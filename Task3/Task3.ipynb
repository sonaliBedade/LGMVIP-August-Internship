# %%
import cv2
from IPython.display import Image
from google.colab.patches import cv2_imshow

# %% [markdown]
# Reading the original image

# %%
image = cv2.imread("friends.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x675 at 0x7F6AB5722ED0>

# %% [markdown]
# Converting original image to grayscale

# %%
gray_image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=1200x675 at 0x7F6AB568CED0>

# %% [markdown]
# Inverting the grayscale image

# %%
inverted_image = 255 - gray_image
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=1200x675 at 0x7F6AB4605090>

# %% [markdown]
# Blurring the image using Gaussian function

# %%
blurred = cv2.GaussianBlur(inverted_image,(21,21),0)
cv2_imshow(blurred)
# Out:
# <PIL.Image.Image image mode=L size=1200x675 at 0x7F6AAFDA0F90>

# %% [markdown]
# Inverting the blurred image

# %%
inverted_blurred = 255 - blurred
cv2_imshow(inverted_blurred)
# Out:
# <PIL.Image.Image image mode=L size=1200x675 at 0x7F6AAFDB3C90>

# %% [markdown]
# Final pencil sketch

# %%
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=1200x675 at 0x7F6AAFD63ED0>
